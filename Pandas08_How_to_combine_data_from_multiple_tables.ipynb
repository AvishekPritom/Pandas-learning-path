# %% [markdown]
# <a href="https://colab.research.google.com/github/AvishekPritom/Pandas-learning-path/blob/main/Pandas08_How_to_combine_data_from_multiple_tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Data loading.....

# %%
air_quality_no2 = pd.read_csv("/content/air_quality_no2_long.csv", parse_dates=True)

# %%
air_quality_no2 = air_quality_no2[["date.utc", "location", "parameter", "value"]]
air_quality_no2.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 2  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 3  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 4  2019-06-20 20:00:00+00:00  FR04014       no2   21.4

# %% [markdown]
# Air quality particulate matter data

# %%
air_quality_pm25 = pd.read_csv("/content/air_quality_pm25_long.csv")

# %%
air_quality_pm25 = air_quality_pm25[["date.utc", "location", "parameter", "value"]]
air_quality_pm25.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-18 06:00:00+00:00  BETR801      pm25   18.0
# 1  2019-06-17 08:00:00+00:00  BETR801      pm25    6.5
# 2  2019-06-17 07:00:00+00:00  BETR801      pm25   18.5
# 3  2019-06-17 06:00:00+00:00  BETR801      pm25   16.0
# 4  2019-06-17 05:00:00+00:00  BETR801      pm25    7.5

# %% [markdown]
# #Concatening Objects

# %% [markdown]
# I want to combine the measurements of
# 𝑁⁢𝑂2
#  and
# 𝑃⁢𝑀25
# , two tables with a similar structure, in a single table.

# %%
air_quality = pd.concat([air_quality_no2, air_quality_pm25], axis = 0)

# %%
air_quality.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 2  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 3  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 4  2019-06-20 20:00:00+00:00  FR04014       no2   21.4

# %% [markdown]
# The concat() function performs concatenation operations of multiple tables along one of the axes (row-wise or column-wise).
#
# By default concatenation is along axis 0, so the resulting table combines the rows of the input tables. Let’s check the shape of the original and the concatenated tables to verify the operation:

# %%
print('Shape of the ``air_quality_pm25`` table: ', air_quality_pm25.shape)
print('Shape of the ``air_quality_no2`` table: ', air_quality_no2.shape)
print('Shape of the ``air_quality``table: ', air_quality.shape)
# Out:
# Shape of the ``air_quality_pm25`` table:  (1110, 4)
# Shape of the ``air_quality_no2`` table:  (2068, 4)
# Shape of the ``air_quality``table:  (3178, 4)

# %% [markdown]
# >The axis argument will return in a number of pandas methods that can be applied along an axis. A DataFrame has two corresponding axes: the first running vertically downwards across rows (axis 0), and the second running horizontally across columns (axis 1). Most operations like concatenation or summary statistics are by default across rows (axis 0), but can be applied across columns as well.

# %% [markdown]
# Sorting the table on the datetime information also illustrates the combination of both tables, with the parameter column defining the origin of the table (either no2 from table air_quality_no2 or pm25 from table air_quality_pm25):

# %%
air_quality.sort_values("date.utc")
# Out:
#                        date.utc            location parameter  value
# 1109  2019-05-07 01:00:00+00:00  London Westminster      pm25    8.0
# 2067  2019-05-07 01:00:00+00:00  London Westminster       no2   23.0
# 1098  2019-05-07 01:00:00+00:00             BETR801       no2   50.5
# 1003  2019-05-07 01:00:00+00:00             FR04014       no2   25.0
# 100   2019-05-07 01:00:00+00:00             BETR801      pm25   12.5
# ...                         ...                 ...       ...    ...
# 2     2019-06-20 22:00:00+00:00             FR04014       no2   26.5
# 102   2019-06-20 23:00:00+00:00  London Westminster      pm25    7.0
# 1     2019-06-20 23:00:00+00:00             FR04014       no2   21.8
# 101   2019-06-21 00:00:00+00:00  London Westminster      pm25    7.0
# 0     2019-06-21 00:00:00+00:00             FR04014       no2   20.0
#
# [3178 rows x 4 columns]

# %%
air_quality_ = pd.concat([air_quality_pm25, air_quality_no2], keys=["PM25", "NO2"])

# %%
air_quality.head()
# Out:
#                     date.utc location parameter  value
# 0  2019-06-21 00:00:00+00:00  FR04014       no2   20.0
# 1  2019-06-20 23:00:00+00:00  FR04014       no2   21.8
# 2  2019-06-20 22:00:00+00:00  FR04014       no2   26.5
# 3  2019-06-20 21:00:00+00:00  FR04014       no2   24.9
# 4  2019-06-20 20:00:00+00:00  FR04014       no2   21.4

# %% [markdown]
# #Join tables using a common identifier

# %% [markdown]
# Add the station coordinates, provided by the stations metadata table, to the corresponding rows in the measurements table.

# %%
air_quality = pd.merge(air_quality_no2, air_quality_pm25, how='left', on='location')

# %%
air_quality.head()
# Out:
#                   date.utc_x location parameter_x  value_x date.utc_y  \
# 0  2019-06-21 00:00:00+00:00  FR04014         no2     20.0        NaN
# 1  2019-06-20 23:00:00+00:00  FR04014         no2     21.8        NaN
# 2  2019-06-20 22:00:00+00:00  FR04014         no2     26.5        NaN
# 3  2019-06-20 21:00:00+00:00  FR04014         no2     24.9        NaN
# 4  2019-06-20 20:00:00+00:00  FR04014         no2     21.4        NaN
#
#   parameter_y  value_y
# 0         NaN      NaN
# 1         NaN      NaN
# 2         NaN      NaN
# 3         NaN      NaN
# 4         NaN      NaN

# %%
air_quality = pd.merge(air_quality_no2, air_quality_pm25, how ="left", left_on="location", right_on="parameter")

# %%
air_quality.head()
# Out:
#                   date.utc_x location_x parameter_x  value_x date.utc_y  \
# 0  2019-06-21 00:00:00+00:00    FR04014         no2     20.0        NaN
# 1  2019-06-20 23:00:00+00:00    FR04014         no2     21.8        NaN
# 2  2019-06-20 22:00:00+00:00    FR04014         no2     26.5        NaN
# 3  2019-06-20 21:00:00+00:00    FR04014         no2     24.9        NaN
# 4  2019-06-20 20:00:00+00:00    FR04014         no2     21.4        NaN
#
#   location_y parameter_y  value_y
# 0        NaN         NaN      NaN
# 1        NaN         NaN      NaN
# 2        NaN         NaN      NaN
# 3        NaN         NaN      NaN
# 4        NaN         NaN      NaN

# %% [markdown]
# Compared to the previous example, there is no common column name. However, the parameter column in the air_quality table and the id column in the air_quality_parameters table both provide the measured variable in a common format. The left_on and right_on arguments are used here (instead of just on) to make the link between the two tables.
